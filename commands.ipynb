# %% [markdown]
# # Commands

# %% [markdown]
# ### 1. Hardware specs

# %%
# !nvaccelinfo

# %%
# !nvfortran 1_hardware.cuf
# !./a.out

# %%
# !nvfortran 2_hardware_simp.cuf
# !./a.out

# %%
# !export cuda_visible_devices=0
# !nvfortran 2_hardware_simp.cuf
# !./a.out
